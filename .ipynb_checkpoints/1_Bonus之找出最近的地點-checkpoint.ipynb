# %%
import requests
import json
import folium

# %%
parking_api = "http://e-traffic.taichung.gov.tw/DataAPI/api/ParkingAPI"
response = requests.get(parking_api)
parking_place = json.loads(response.text)

# %%
whereami = (121.705234, 26.212272)

# %%
x = [0, 2, 3, 4, 5, 6, 7, 8, -9, 0]

# %%
def f(t):
    return abs(5 - t)

x.sort(key=f)
print(x)
# Out:
# [5, 4, 6, 3, 7, 2, 8, 0, 0, -9]

# %%
parking_place.sort(key=lambda t: abs(complex(t['X'],t['Y'])-complex(*whereami)))

# %%
avg_X = sum(i['X'] for i in parking_place) / len(parking_place)
avg_Y = sum(i['Y'] for i in parking_place) / len(parking_place)

# %%
abs(complex(120.67919, 24.0995)-120.649638+24.120551j)
# Out:
# 48.220060055575466

# %%
abs(complex(120.67919, 24.0995)-(120.649638+24.120551j))
# Out:
# 0.03628312700141159

# %%
abs((120.67919+24.0995j) - (120.649638+24.120551j))
# Out:
# 0.03628312700141159

# %%
abs((120.649638+24.120551j) - (120.649638+24.120551j))
# Out:
# 0.0

# %%
map_1 = folium.Map(location=[avg_Y, avg_X], zoom_start=12)

# %%
for i in parking_place[:30]:
    marker = folium.Marker(location=[i['Y'], i['X']], popup=i['Position'])
    map_1.add_child(marker)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
